# %%
# Data Structures - Lists (Collections) , mutable

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print([1,24,76])
# Out:
# [1, 24, 76]

# %%
print(['red','yellow','blue'])
# Out:
# ['red', 'yellow', 'blue']

# %%
print(['red',24,98.6])
# Out:
# ['red', 24, 98.6]

# %%
print([1,[5,6],7])
# Out:
# [1, [5, 6], 7]

# %%
print([1,(5,6),7])
# Out:
# [1, (5, 6), 7]

# %%
print([])
# Out:
# []

# %%
# an example
for i in [5,4,3,2,1]:
  print(i)
print('Blastoff!')
# Out:
# 5
# 4
# 3
# 2
# 1
# Blastoff!

# %%
friends = ['Joseph', 'Glenn', 'Sally']
for friend in friends:
  print('Happy New Year: ', friend)
print('Done')
# Out:
# Happy New Year:  Joseph
# Happy New Year:  Glenn
# Happy New Year:  Sally
# Done

# %%
#alternate way of writing the above program
z = ['Joseph', 'Glenn', 'Sally']
for x in z:
  print('Happy New Year: ', x)
print('Done')
# Out:
# Happy New Year:  Joseph
# Happy New Year:  Glenn
# Happy New Year:  Sally
# Done

# %%
# Indexing in lists
friends = ['Joseph', 'Glenn', 'Sally']
print(friends[1])
# Out:
# Glenn

# %%
fruit = 'Banana'
fruit[0] = 'b'    # Strings are immutable. (Cannot be changed)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2bc78b004470> in <module>()
#       1 fruit = 'Banana'
# ----> 2 fruit[0] = 'b'
#
# TypeError: 'str' object does not support item assignment

# %%
x = fruit.lower()
print(x)
# Out:
# banana

# %%
lotto = [2,14,26,41,63]
print(lotto)
# Out:
# [2, 14, 26, 41, 63]

# %%
lotto[2] = 28
print(lotto)    # Lists are mutable
# Out:
# [2, 14, 28, 41, 63]

# %%
greet =  'Hello Bob'
print(len(greet))
# Out:
# 9

# %%
x = [1,2,'joe','99']
print(len(x))
# Out:
# 4

# %%
# 'range' keyword

# %%
print(range(4))
# Out:
# range(0, 4)

# %%
friends = ['Joseph', 'Glenn', 'Sally']
print(len(friends))
# Out:
# 3

# %%
print(range(len(friends)))
# Out:
# range(0, 3)

# %%
friends = ['Joseph', 'Glenn', 'Sally']
for friend in friends:
  print('Happy New Year: ', friend)
print('Done')
# Out:
# Happy New Year:  Joseph
# Happy New Year:  Glenn
# Happy New Year:  Sally
# Done

# %%
friends = ['Joseph', 'Glenn', 'Sally']
for i in range(len(friends)):
  friend = friends[i]
  print('Happy New Year: ', friend)
print('Done')
# Out:
# Happy New Year:  Joseph
# Happy New Year:  Glenn
# Happy New Year:  Sally
# Done

# %%
# Loop operations

# %%
# Concatenating lists
a = [1,2,3]
b = [4,5,6]
c = a + b
print(c)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a)
# Out:
# [1, 2, 3]

# %%
t = [9,41,12,3,74,15]
t[1:3]
# Out:
# [41, 12]

# %%
t[:4]
# Out:
# [9, 41, 12, 3]

# %%
t[3:]
# Out:
# [3, 74, 15]

# %%
t[:]
# Out:
# [9, 41, 12, 3, 74, 15]

# %%
x = list()
type(x)
# Out:
# list

# %%
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
stuff = list()
stuff.append('book')
stuff.append(99)
print(stuff)
# Out:
# ['book', 99]

# %%
stuff.append('cookie')
print(stuff)
# Out:
# ['book', 99, 'cookie']

# %%
# 'in' operator
some = [1,9,21,10,16]
9 in some
# Out:
# True

# %%
13 in some
# Out:
# False

# %%
20 not in some
# Out:
# True

# %%
friends = ['Joseph', 'Glenn', 'Sally']
friends.sort()
print(friends)
# Out:
# ['Glenn', 'Joseph', 'Sally']

# %%
print(friends[1])
# Out:
# Joseph

# %%
friends = ['Joseph', 'Glenn', 'Sally']
new = friends.sort()
print(friends)
print(new)
# Out:
# ['Glenn', 'Joseph', 'Sally']
# None

# %%
friends = ['Joseph', 'Glenn', 'Sally']
new = sorted(friends)
print(friends)
print(new)
# Out:
# ['Joseph', 'Glenn', 'Sally']
# ['Glenn', 'Joseph', 'Sally']

# %%
nums = [3,41,12,9,74,15]
print(len(nums))
print(max(nums))
print(min(nums))
print(sum(nums))
print(sum(nums)/len(nums))
# Out:
# 6
# 74
# 3
# 154
# 25.666666666666668

# %%
# finding the average of given numbers
total = 0
count = 0
while True:
  inp = input('Enter a number: ')
  if inp =='done': break
  value = float(inp)
  total = total + value
  count = count + 1

average = total / count
print('Average:', average)
# Out:
# Enter a number: 3
# Enter a number: 5
# Enter a number: 9
# Enter a number: done
# Average: 5.666666666666667

# %%
# finding the average of given numbers (using list)
numlist = list()
while True:
  inp = input('Enter a number: ')
  if inp =='done': break
  value = float(inp)
  numlist.append(value)

average = sum(numlist) / len(numlist)
print('Average:', average)
# Out:
# Enter a number: 3
# Enter a number: 5
# Enter a number: 9
# Enter a number: done
# Average: 5.666666666666667

# %%
# Strings Vs Lists

# %%
abc = 'With three words'
stuff = abc.split()
print(stuff)
# Out:
# ['With', 'three', 'words']

# %%
print(len(stuff))
print(stuff[0])
# Out:
# 3
# With

# %%
for w in stuff: 
  print(w)
# Out:
# With
# three
# words

# %%
line = "A lot         of spaces"
etc = line.split()
print(etc)
# Out:
# ['A', 'lot', 'of', 'spaces']

# %%
line = 'first;second;third'
thing = line.split()
print(thing)
print(len(thing))             # default delimiter is a 'space'
# Out:
# ['first;second;third']
# 1

# %%
line = 'first;second;third'
thing = line.split(';')
print(thing)
print(len(thing))
# Out:
# ['first', 'second', 'third']
# 3

# %%
line = 'From stephan.marquard@uct.ac.za Sat Jan  5  09:14:16 2008'
words = line.split()
print(words)
# Out:
# ['From', 'stephan.marquard@uct.ac.za', 'Sat', 'Jan', '5', '09:14:16', '2008']

# %%
fhand = open('/content/drive/MyDrive/Colab Notebooks/mbox-short.txt')
for line in fhand:
  line = line.rstrip()
  if not line.startswith('From '): continue
  words = line.split()
  print(words[2])
# Out:
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu

# %%
line = 'From stephan.marquard@uct.ac.za Sat Jan  5  09:14:16 2008'
words = line.split()
email = words[1]
pieces = email.split('@')
print(pieces[1])
# Out:
# uct.ac.za

# %%
# Strings, files, lists and Guardian pattern

# %%
fhand = open('/content/drive/MyDrive/Colab Notebooks/mbox-short.txt')
for line in fhand:
  line = line.rstrip()
  #print('Line: ', line)
  wds = line.split()
  #print('Words: ', wds)
  # Guardian
  if len(wds) < 1:
    continue
  if wds[0] != 'From':
   # print('Ignore')
    continue
  print(wds[2])
# Out:
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu

# %%
fhand = open('/content/drive/MyDrive/Colab Notebooks/mbox-short.txt')
for line in fhand:
  line = line.rstrip()
  #print('Line: ', line)
  #Guardian
  if line == '':
    #print('Skip Blank')
    continue
  wds = line.split()
  #print('Words: ', wds)
  if wds[0] != 'From':
   # print('Ignore')
    continue
  print(wds[2])
# Out:
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu

# %%
fhand = open('/content/drive/MyDrive/Colab Notebooks/mbox-short.txt')
for line in fhand:
  line = line.rstrip()
  #print('Line: ', line)
  wds = line.split()
  #print('Words: ', wds)
  # Guardian a bit stronger
  if len(wds) < 3:
    continue
  if wds[0] != 'From':
   # print('Ignore')
    continue
  print(wds[2])
# Out:
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu

# %%
fhand = open('/content/drive/MyDrive/Colab Notebooks/mbox-short.txt')
for line in fhand:
  line = line.rstrip()
  #print('Line: ', line)
  wds = line.split()
  #print('Words: ', wds)
  # Guardian in a compound statement
  if len(wds) < 3 or wds[0] != 'From':
    continue
  print(wds[2])
# Out:
# Sat
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Fri
# Thu
# Thu
# Thu
# Thu
# Thu
# Thu
