# %%
# Variables, Expressions and Statements

# Constants

print(123)
# Out:
# 123

# %%
print(98.6)
# Out:
# 98.6

# %%
print("Hello world")
# Out:
# Hello world

# %%
# Researved words :

# %%
# variables (case sensitive)
x = 12.2
y = 14

print(x,y)

x = 100

print(x,y)
# Out:
# 12.2 14
# 100 14

# %%
#Example for (long and uninsightful)
# bad way of assigning variable names

x1q3z9ocd = 35.0
x1q3z9afd = 12.50
x1q3p9afd = x1q3z9ocd * x1q3z9afd
print(x1q3p9afd)
# Out:
# 437.5

# %%
#Example for (short and uninsightful)

# ok way of assigning variable names
a = 35.0
b = 12.50
c = a * b
print(c)
# Out:
# 437.5

# %%
#Example for (mnenomic variable names - reasonably short and meaningful variable names)

# best way of assigning variable names
hours = 35.0
rate = 12.50
pay = hours * rate
print(pay)
# Out:
# 437.5

# %%
x = 2
x = x + 2
print(x)
# Out:
# 4

# %%
x = 0.6
x = 3.9 * x * (1-x)
print(x)
# Out:
# 0.9359999999999999

# %%
# Expressions (more complex calculations)

# + =  addition, - = subtraction, * = multiplication, / = Division, ** = Power, % = modulo division remainder

# %%
xx = 2
xx = xx+2
print(xx)

yy = 440 *12
print(yy)

zz= yy/1000
print(zz)

jj = 23
kk = jj%5
print(kk)

print(4**3)
# Out:
# 4
# 5280
# 5.28
# 3
# 64

# %%
# Operator Precedence (Parenthesis, Power, Multiplication, Addition, left to right)
x = 1+2*3-4/5**6
print(x)

# equivalent to 
y = 1+(2*3)-(4/(5**6))
print(y)
# Out:
# 6.999744
# 6.999744

# %%
# Concatenate (types of data)

ddd = 1 + 4
print(ddd)

eee = 'hello'+'there'
print(eee)
# Out:
# 5
# hellothere

# %%
eee = 'hello'+'there'
eee = eee + 1
print(eee)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-70d449a0b9c4> in <module>()
#       1 eee = 'hello'+'there'
# ----> 2 eee = eee + 1
#       3 print(eee)
#
# TypeError: can only concatenate str (not "int") to str

# %%
eee = 'hello'+'there'
type(eee)
# Out:
# str

# %%
type(1)
# Out:
# int

# %%
xx = 1
type(xx)
# Out:
# int

# %%
temp = 98.6
type(temp)
# Out:
# float

# %%
type(1)
# Out:
# int

# %%
type(1.0)
# Out:
# float

# %%
print(float(99)+100)
# Out:
# 199.0

# %%
i = 42
type(i)
# Out:
# int

# %%
f = float(i)
print(f)
# Out:
# 42.0

# %%
type(f)
# Out:
# float

# %%
# Division (always returns a floating point)

print(10/2)
# Out:
# 5.0

# %%
print(9/2)
print(99/100)
print(10.0/2.0)
print(99.0/100.0)
# Out:
# 4.5
# 0.99
# 5.0
# 0.99

# %%
sval = '123'
type(sval)
# Out:
# str

# %%
print(sval + 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-844c8fe77d11> in <module>()
# ----> 1 print(sval + 1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
ival = int(sval)
type(ival)
# Out:
# int

# %%
print(ival + 1)
# Out:
# 124

# %%
nsv = 'hello bob'
niv = int(nsv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-de8bd31b3c29> in <module>()
#       1 nsv = 'hello bob'
# ----> 2 niv = int(nsv)
#
# ValueError: invalid literal for int() with base 10: 'hello bob'

# %%
# Input function

nam = input('Who are you? ')
print('Welcome', nam)
# Out:
# Who are you? Vinay
# Welcome Vinay

# %%
inp = input('Europe floor? ')
usf = inp + 1
print('US floor', usf) # Input always gives a string
# Out:
# Europe floor? 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-fc67e1d4727f> in <module>()
#       1 inp = input('Europe floor? ')
# ----> 2 usf = inp + 1
#       3 print('US floor', usf)
#
# TypeError: can only concatenate str (not "int") to str

# %%
inp = input('Europe floor? ')
usf = int(inp) + 1
print('US floor', usf)
# Out:
# Europe floor? 4
# US floor 5

# %%
# Comments always starts with a # sign. An example is shown below.


# Get the name of the file and open it
name = input("enter file : ")
handle = open(name, 'r')

#Count word frequency
counts = dict()
for line in handle:
  words = line.split()
  for word in words:
    counts[word] = counts.get(word,0)+1

# Find the most common word
bigcount = None
bigword = None
for word,count in counts.items():
  if bigcount is None or count> bigcount:
    bigword = word
    bigcount = count

# all done
print(bigword,bigcount)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# ...
