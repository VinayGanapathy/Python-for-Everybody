# %%
# Strings

# %%
str1 = "Hello"
str2 = "there"
bob = str1 + str2
print(bob)
# Out:
# Hellothere

# %%
str3 = '123'
str3 = str3 + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a3c2e55be021> in <module>()
#       1 str3 = '123'
# ----> 2 str3 = str3 + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = int(str3) + 1
print(x)
# Out:
# 124

# %%
name = input ('Enter: ')
print(name)
# Out:
# Enter: chuck
# chuck

# %%
apple = input ('Enter: ')
x = apple - 10
# Out:
# Enter: 100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-bdb5ba0afd40> in <module>()
#       1 apple = input ('Enter: ')
# ----> 2 x = apple - 10
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
x = int(apple) - 10
print(x)
# Out:
# 90

# %%
fruit = 'banana'
letter = fruit[1]
print(letter)
# Out:
# a

# %%
x = 3
w = fruit[x -1]
print(w)
# Out:
# n

# %%
zot = 'abc'
print(zot[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-6acb855f1a9c> in <module>()
#       1 zot = 'abc'
# ----> 2 print(zot[5])
#
# IndexError: string index out of range

# %%
fruit = 'banana'
print(len(fruit))
# Out:
# 6

# %%
fruit = 'banana'
index = 0
while index < len(fruit):
  letter = fruit[index]
  print(index, letter)
  index = index + 1
# Out:
# 0 b
# 1 a
# 2 n
# 3 a
# 4 n
# 5 a

# %%
fruit = 'banana'                  # the word 'in' is similar to the 'set' mathematical notation
for letter in fruit:
  print(letter)
# Out:
# b
# a
# n
# a
# n
# a

# %%
# Finding a specific letter in a word and counting its repetetion (counter)
word = 'banana'
count = 0
for letter in word:
  if letter == 'a':
    count = count +1
print(count)
# Out:
# 3

# %%
# More string operations

# %%
# Slicing 'strings'

s = 'Monty Python'
print(s[0:4])
# Out:
# Mont

# %%
s = 'Monty Python'
print(s[6:7])
# Out:
# P

# %%
s = 'Monty Python'
print(s[6:20])
# Out:
# Python

# %%
s = 'Monty Python'
print(s[:2])
# Out:
# Mo

# %%
s = 'Monty Python'
print(s[8:])
# Out:
# thon

# %%
s = 'Monty Python'
print(s[:])
# Out:
# Monty Python

# %%
s = 'Monty Python'
print(s[::-1])
# Out:
# nohtyP ytnoM

# %%
a = 'Hello'
b = a + 'There'
print(b)
# Out:
# HelloThere

# %%
c = a + ' ' + 'There'
print(c)
# Out:
# Hello There

# %%
fruit = 'banana'
'n' in fruit
# Out:
# True

# %%
'm' in fruit
# Out:
# False

# %%
'nan' in fruit
# Out:
# True

# %%
if 'a' in fruit:
  print('Found it')
# Out:
# Found it

# %%
if word == 'banana':
  print('All right, bananas.')
# Out:
# All right, bananas.

# %%
word = 'a'
if word < 'banana':
  print('Your word,'+ word +', comes before banana')
elif word > 'banana':
  print('Your word,'+ word +', comes after banana')
else:
  print('All right, bananas.')
# Out:
# Your word,a, comes before banana

# %%
word = 'c'
if word < 'banana':
  print('Your word,'+ word +', comes before banana')
elif word > 'banana':
  print('Your word,'+ word +', comes after banana')
else:
  print('All right, bananas.')
# Out:
# Your word,c, comes after banana

# %%
greet = 'Hello Bob'
zap = greet.lower()
print(zap)
print(greet)
print('Hi There'.lower())
print('Hi There'.upper())
# Out:
# hello bob
# Hello Bob
# hi there
# HI THERE

# %%
stuff = 'Hello world'
type(stuff)
# Out:
# str

# %%
dir(stuff)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
# String library - Commonly used string commands

# str.capitalize
# str.center(width[,fillchar])
# str.endswith(suffix[, start[, end]])
# str.find(sub[,start[,end]])
# str.lstrip()
# str.replace(old,new[,count])
# str.lower()
# str.rstrip([chars])
# str.strip([chars])
# str.upper()

# %%
fruit = "banana"
pos = fruit.find('na')
print(pos)
# Out:
# 2

# %%
aa = fruit.find('z')
print(aa)
# Out:
# -1

# %%
greet = 'Hello Bob'
nnn = greet.upper()
print(nnn)
# Out:
# HELLO BOB

# %%
www = greet.lower()
print(www)
# Out:
# hello bob

# %%
greet = 'Hello Bob'
nstr = greet.replace('Bob', 'Jane')
print(nstr)
# Out:
# Hello Jane

# %%
nstr = greet.replace('o', 'X')
print(nstr)
# Out:
# HellX BXb

# %%
greet = '     Hello Bob     '
print(greet.lstrip())
print(greet.rstrip())
print(greet.strip())
# Out:
# Hello Bob
#      Hello Bob
# Hello Bob

# %%
line = 'Please have a nice day'
line.startswith('Please')
# Out:
# True

# %%
line.startswith('p')
# Out:
# False

# %%
data = 'From stephan.marquard@uct.ac.za Sat Jan  5  09:14:16 2008'
atpos = data.find('@')
print(atpos)

sppos = data.find(' ', atpos)
print(sppos)

host = data[atpos+1:sppos]
print(host)
# Out:
# 21
# 31
# uct.ac.za
